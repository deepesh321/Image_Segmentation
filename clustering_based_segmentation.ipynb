# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
pic1 = plt.imread('/home/deepesh/Downloads/akshay.jpg')/255  # dividing by 255 to bring the pixel values between 0 and 1
print(pic1.shape)
plt.imshow(pic1)
# Out:
# (539, 960, 3)

# %%
pic=pic1.reshape(pic1.shape[0]*pic1.shape[1],pic1.shape[2])
pic.shape
# Out:
# (517440, 3)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=7, random_state=0).fit(pic)
pic = kmeans.cluster_centers_[kmeans.labels_]

# %%
pic = pic.reshape(pic1.shape[0], pic1.shape[1], pic1.shape[2])
plt.imshow(pic)
